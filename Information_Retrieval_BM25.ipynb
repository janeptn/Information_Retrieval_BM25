# %%
# Importando as bibliotecas
import os
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

# %%
# Funções

def load_cisi(corpus_path, query_path):
    """Carrega o corpus e as consultas da coleção CISI"""

    with open(corpus_path, 'r') as f:
        corpus = f.read()

    queries = pd.read_csv(query_path, sep='\n', header=None)
    queries = queries[queries.index % 2 == 0].reset_index(drop=True)
    queries.columns = ['query']
    queries['query'] = queries['query'].str.replace('^ *(\d+)', '')
    queries = queries.reset_index(drop=True)
 
      
    return corpus, queries


def preprocess_text(text):
    """Realiza preprocessamento de um documento"""

    return text.lower()


def compute_idf(corpus):
    """Calcula a frequência inversa do documento (IDF) de cada termo no corpus"""

    count_vectorizer = CountVectorizer(preprocessor=preprocess_text, token_pattern=r'\b\w+\b')
    term_counts = count_vectorizer.fit_transform([corpus])
    idf = np.log(len(term_counts.toarray()) / np.sum(term_counts.toarray() > 0, axis=0))
    idf = np.asarray(idf).squeeze()

    return idf


def compute_bm25_weights(corpus, queries, k1=1.2, b=0.75):
    """Calcula os pesos BM25 para o corpus e as consultas"""

    # Transforma o corpus em uma matriz termo-documento
    count_vectorizer = CountVectorizer(preprocessor=preprocess_text, token_pattern=r'\b\w+\b')
    term_counts = count_vectorizer.fit_transform([corpus])

    # Calcula a frequência inversa do documento (IDF) de cada termo no corpus
    idf = compute_idf(corpus)

    # Transforma a matriz termo-documento em uma matriz TF-IDF
    tfidf_transformer = TfidfTransformer()
    tfidf = tfidf_transformer.fit_transform(term_counts)

    # Calcula os pesos BM25 para cada consulta
    weights = []
    for query in queries:
        # Transforma a consulta em um vetor de termos
        query_vec = count_vectorizer.transform([query])
        query_vec = np.squeeze(np.asarray(query_vec.sum(axis=0)))

        # Calcula o denominador da fórmula BM25
        K = k1 * ((1 - b) + b * (len(term_counts.toarray()[0]) / np.mean(np.sum(term_counts.toarray(), axis=1))))

        # Calcula o numerador da fórmula BM25 para cada documento
        scores = ((k1 + 1) * tfidf).multiply(query_vec * idf)
        scores = np.asarray(scores.sum(axis=1)).reshape(-1)
        scores /= K + scores


        # Adiciona os pesos BM25 para a consulta atual à lista de resultados
        weights.append(scores)

    return weights

# %%
# Carrega o corpus e as consultas
corpus_path = 'CISI.ALL'
query_path = 'CISI.QRY'
corpus, queries = load_cisi(corpus_path, query_path)

# Calcula os pesos BM25 para o corpus e as consultas
bm25_weights = compute_bm25_weights(corpus, queries['query'].tolist())

# Exibe os resultados
for i, query in enumerate(queries['query']):
    print(f"Query {i + 1}: {query}")
# Out:
# <ipython-input-3-a7aeba750c11>:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   queries['query'] = queries['query'].str.replace('^ *(\d+)', '')
# Query 1: .I 1
# Query 2: What problems and concerns are there in making up descriptive titles?
# Query 3: approximate titles?
# Query 4: .I 2
# Query 5: How can actually pertinent data, as opposed to references or entire articles
# Query 6: .I 3
# Query 7: What is information science?  Give definitions where possible.
# Query 8: .W
# Query 9: transforming printed text into computer-ready form.
# Query 10: .W
# Query 11: information management and unobstructed use of information retrieval systems?
# Query 12: .I 6
# Query 13: What possibilities are there for verbal communication between computers and
# Query 14: .I 7
# Query 15: Describe presently working and planned systems for publishing and printing
# Query 16: data-processing form, for further use in retrieval.
# Query 17: .W
# Query 18: What bearing does it have on the science in general?
# Query 19: .W
# Query 20: of articles for inclusion in an information retrieval system?
# Query 21: .W
# Query 22: .I 11
# Query 23: What is the need for information consolidation, evaluation, and retrieval in
# Query 24: .I 12
# Query 25: Give methods for high speed publication, printing, and distribution of
# Query 26: .I 13
# Query 27: What criteria have been developed for the objective evaluation of information
# Query 28: .I 14
# Query 29: What future is there for automatic medical diagnosis?
# Query 30: .W
# Query 31: automated libraries, cost?
# Query 32: .I 16
# Query 33: What systems incorporate multiprogramming or remote stations in information
# Query 34: .I 17
# Query 35: Means of obtaining large volume, high speed, customer usable
# Query 36: .I 18
# Query 37: What methods are there for encoding, automatically matching,
# Query 38: like the structural formulas for chemical compounds?
# Query 39: .W
# Query 40: Coding and matching methods.
# Query 41: .W
# Query 42: .I 21
# Query 43: The need to provide personnel for the information field.
# Query 44: .W
# Query 45: .I 23
# Query 46: Amount of use of books in libraries.
# Query 47: .I 24
# Query 48: Educational and training requirements for personnel in the information field.
# Query 49: .I 25
# Query 50: International systems for exchange and dissemination of information.
# Query 51: .W
# Query 52: .I 27
# Query 53: Computerized information retrieval systems.  Computerized indexing systems.
# Query 54: .W
# Query 55: .I 29
# Query 56: Specific advantages of computerized index systems.
# Query 57: .W
# Query 58: .I 31
# Query 59: Information systems in the physical sciences.
# Query 60: .W
# Query 61: Problems and methods of automated general author and title indexing systems.
# Query 62: .W
# Query 63: to the user from a distance.
# Query 64: .W
# Query 65: .I 35
# Query 66: Government supported agencies and projects dealing with information dissemination.
# Query 67: .W
# Query 68: texts from one national language to another?  How can machine translating
# Query 69: of meaning in languages of different structures?
# Query 70: .W
# Query 71: available?  Wanted are lists of terms that are descriptive vocabularies
# Query 72: in meaningful schemes.  Wanted are lists that have been tested, at least to
# Query 73: .I 38
# Query 74: How can access words in an information retrieval system be kept up to date?
# Query 75: What definitions of the problem and progress toward solutions have been made
# Query 76: words, or other symbols used for getting at stored data?
# Query 77: .W
# Query 78: and dislocation of personnel.  Training and retraining of people to use
# Query 79: technicians, students, researchers, and even executives will need education
# Query 80: What programs have been developed to change the attitudes and skills of
# Query 81: .I 40
# Query 82: What is the status of machine translation?  What progress has been
# Query 83: with some degree of automation?  What problems and stumbling blocks
# Query 84: or only challenging to the field of documentation on an international scale?
# Query 85: .W
# Query 86: information retrieval?  What studies have been done to compare the
# Query 87: Is there a generally accepted form of arranging material in
# Query 88: without going to a great amount of effort?
# Query 89: .W
# Query 90: vocabulary of information retrieval.  It appears important that this
# Query 91: articles would provide an understanding of the various important aspects
# Query 92: .I 43
# Query 93: The difficulties encountered in information retrieval systems are often
# Query 94: adequately for document analysis, indexing, and machine coding.  The
# Query 95: in which the equipment will understand.  What articles have been written
# Query 96: .I 44
# Query 97: There are presently fifty to one hundred technical journals being
# Query 98: the many journals published, one to two million articles appear every
# Query 99: scientific and technical publication in terms of analysis, control,
# Query 100: .I 45
# Query 101: I am looking for information about the impact of automation on
# Query 102: the increasing importance of automation in view of the proliferation of
# Query 103: this problem.  How will automation affect libraries and how should they
# Query 104: .I 46
# Query 105: I am seeking information on the use of data processing in libraries and
# Query 106: like descriptions of both general and specific applications of
# Query 107: serial records, and other record-keeping.  Examples should be based on
# Query 108: practices in a special library which could also be applied in a public
# Query 109: both present and projected.
# Query 110: .W
# Query 111: of material about information retrieval?  If there is, does it take
# Query 112: distributes information retrieval methods and research results?  If
# Query 113: boundaries?  What seem to have been some of the problems blocking a
# Query 114: some of those problems?
# Query 115: .W
# Query 116: line distinguishing research and practice is often difficult - even
# Query 117: on information retrieval?  If so, in which countries are they
# Query 118: libraries?  Can information retrieval as a specialized research
# Query 119: from other fields, such as mathematics, engineering, and library
# Query 120: .I 49
# Query 121: Most resources have been spent on applying information retrieval
# Query 122: retrieval been used at all in the natural sciences, social sciences,
# Query 123: been encountered with these subject areas and how have they been
# Query 124: necessitated the development of new information retrieval techniques?
# Query 125: .I 50
# Query 126: Is there any use for traditional classification schemes - DDC, UDC, LC,
# Query 127: appears most suited to machine use and where has it been applied?
# Query 128: Has research shown that a subject classification of knowledge is
# Query 129: been devised which appear to be more suited to machine use?
# Query 130: .W
# Query 131: what use are descriptors in the construction of an index?  How can
# Query 132: .I 52
# Query 133: What are the characteristics of MEDLARS (Medical Literature Analysis
# Query 134: National Library of Medicine?  How does it index current medical
# Query 135: What are the major components of the MEDLARS project and its major operating
# Query 136: .I 53
# Query 137: How can the computer be used in medical science for diagnostic and
# Query 138: been tried in hospitals?  If so, what have been the results?
# Query 139: medicine?  For what purposes can an automated system of clinical
# Query 140: .I 54
# Query 141: What is the effect on librarians of automation?  Note the new types
# Query 142: the status, position, and function of the librarians.  What changes
# Query 143: into the education of librarians?
# Query 144: .W
# Query 145: and retrieval system (MEDLARS)?  How does MEDLARS operate?  What are
# Query 146: systems?
# Query 147: .W
# Query 148: through the use of the alphabetically arranged card catalog or the
# Query 149: LC.  Can these systems be modified for use with automated information
# Query 150: .I 57
# Query 151: In catalogs which are either arranged alphabetically or arranged by
# Query 152: ultimately important because the individual looking for information
# Query 153: (probably English in our case) in mind.  Will LC entries and subject
# Query 154: .I 58
# Query 155: Directions in Library Networking
# Query 156: Avram, H.D.
# Query 157: .W
# Query 158: of keying into online systems brought an interdependence among libraries,
# Query 159: process and distribute data.  From this has developed the basic network
# Query 160: of major networks has brought problems in standardization and coordination.
# Query 161: of automated library services, new developments are now pushing toward
# Query 162: this new environment.
# Query 163: (JASIS, Vol. 31, No. 6, November 1980, pp. 438-444)
# Query 164: .T
# Query 165: System
# Query 166: Bennion, B.C.
# Query 167:     The retrieval performance of book indexes can be measured in terms of
# Query 168: but not location is known.  The method requires human searchers to base
# Query 169: test queries, natural or contrived.  It circumvents the need for relevance
# Query 170: approximately to the recall and precision ratios of large document retrieval
# Query 171: indexing of two major encyclopedias showed one encyclopedia apparently
# Query 172: performance.  The method is presently best suited for comparative testing
# Query 173: established.
# Query 174: (JASIS, Vol. 31, No. 4, July 1980, pp. 264-270)
# Query 175: .T
# Query 176: Retrieval
# Query 177: Bichteler, J.
# Query 178: .W
# Query 179: coupling of documents and their cocitations (both cited and citing papers)
# Query 180: bibliographic coupling.  The test collection consisted of 1712 papers whose
# Query 181: effect of using cocitation data, we calculated for each query two measures
# Query 182: Papers were then sorted by the similarity measures, producing two ordered
# Query 183: relevance, and non-relevance to the user's evaluations of the same papers.
# Query 184: similarity measure, representing the introduction of cocitation data,
# Query 185: .B
# Query 186: .I 61
# Query 187: Searching Biases in Large Interactive Document Retrieval Systems
# Query 188: Blair, D.C.
# Query 189:     The way that individuals construct and modify search queries on a
# Query 190: similar to those that have been demonstrated in experiments on judgements
# Query 191: subjects and cause the inquirer searching for documents on a large interactive
# Query 192: is suggested that helps the inquirer to avoid the effect of these biases.
# Query 193: (JASIS, Vol. 31, No. 4, July 1980, pp. 271-277)
# Query 194: .T
# Query 195: .A
# Query 196: .W
# Query 197: represent the relative importance of various index terms in a Boolean
# Query 198: The character of classical Boolean systems is reviewed and related to the
# Query 199: concept of a fuzzy request in which weights are assigned to index terms.
# Query 200: systems retain the manipulability of traditional Boolean requests.
# Query 201: (JASIS, Vol. 31, No. 4, July 1980, pp. 240-247)
# Query 202: .T
# Query 203: Commercial Search Service
# Query 204: Boyle, S.O.
# Query 205: .W
# Query 206: comparative searching and evaluation of an in-house information system
# Query 207: evaluated on the basis of their usefulness in various kinds of searching,
# Query 208: in user type or specific applications.  Some common features of the
# Query 209: dictionary display, and truncation, are seen to be unnecessary or
# Query 210: therefore, detald consideration must be given to the applications,
# Query 211: serve as a useful standard for comparative evaluation, one must be
# Query 212: .B
# Query 213: .I 64
# Query 214: Measurement in Information Science:  Objective and Subjective Metrical Space
# Query 215: Brookes, B.C.
# Query 216:     It is argued that in information science we have to distinguish
# Query 217: information space.  These two spaces are like maps and landscapes: each
# Query 218: easily made once the two spaces are distinguished.  If the transformations
# Query 219: .B
# Query 220: .I 65
# Query 221: A Model of Cluster Searching Based on Classification
# Query 222: Croft, W.B.
# Query 223:     The use of document clusters has been suggested as an efficient file
# Query 224: using this information about the relationships between documents that the
# Query 225: from non-relevant documents) may also be improved.  In this paper a
# Query 226: described.  This model is tested with retrieval experiments which indicate
# Query 227: searches based on other models.  It can also be more effective than a full
# Query 228: aspects of the implementation of the model are discussed.
# Query 229: (Inform. Systems, Vol. 5, No. 3, 1980, pp. 189-195)
# Query 230: .T
# Query 231: .A
# Query 232: .W
# Query 233: physical and functional aspects of networks.  Three types of networks are
# Query 234: that provide bibliographic files (e.g., OCLC, Inc., RLIN), and service
# Query 235: evolves more services will be provided outside the library directly to the
# Query 236: .B
# Query 237: .I 67
# Query 238: The Use of Titles for Automatic Document Classification
# Query 239: Hamill, K.A.
# Query 240: .W
# Query 241: documents according to the 80 sections and five major section groupings of
# Query 242: supplemented by heuristics.  During the "training" phase, words from
# Query 243: of each word in each section of CA is computed and stored in a reference
# Query 244: title against the dictionary and assigns a section number to the document
# Query 245: techniques are used to normalize word variants such as plurals, past
# Query 246: phase.  The dictionary lookup technique is supplemented by the analysis of
# Query 247: the section to which the documents are assigned.  Program performance and
# Query 248: against the published sections of CA and by conducting an experiment with
# Query 249: program assigned approximately 78% of the documents to the correct major
# Query 250: at a rate of 100 documents per second.
# Query 251: (JASIS, Vol. 31, No. 6, November 1980, pp. 396-402)
# Query 252: .T
# Query 253: .A
# Query 254: Willett, P.
# Query 255:     Some of the automatic classification procedures used in information
# Query 256: matrix, the computation of which involves comparing each of the documents
# Query 257: that many of these comparisons, specifically those between documents
# Query 258: file to the document collection.  This communication shows that the
# Query 259: only if the documents are each indexed by a limited number of indexing
# Query 260: several times over and the computation will be greater than when
# Query 261: .B
# Query 262: .I 69
# Query 263: The Application of a Minicomputer to Thesaurus Construction
# Query 264: Kazlauskas, E.J.
# Query 265: .W
# Query 266: for the National Information Center for Special Education Materials
# Query 267: edit, and correct candidate thesaurus terms.  The use of the minicomputer
# Query 268: facilitates the generation of products useful in vocabulary review and in
# Query 269: identification numbers, are altered easily in the design phase to reflect
# Query 270: readable form, it is simple to prepare print programs to provide permuted,
# Query 271: use of the minicomputer facilitates initial thesaurus entry development by
# Query 272: times.
# Query 273: (JASIS, Vol. 31, No. 5, September 1980, pp. 363-368)
# Query 274: .T
# Query 275: .A
# Query 276: .W
# Query 277: computers within the decision making process.  The term has become a
# Query 278: Management Science and Management Information Systems fields have become
# Query 279: not well defined.  For some writers, DSS simply mean interactive systems
# Query 280: system.  They focus on understanding and improving the decision process;
# Query 281: researchers view DSS as a subfield of MIS, while others regard it as an
# Query 282: Support as providing managers with access to data and the latter as giving
# Query 283:     The key argument of this paper is that the term DSS is relevant to
# Query 284: adaptive process of learning and evolution.  The design strategy must
# Query 285: Science and Data Processing approaches.  The research issued for DSS
# Query 286: representation of tasks and user behavior, design architecture and
# Query 287: .B
# Query 288: .I 71
# Query 289: An Automatic Method for Extracting Significant
# Query 290: .A
# Query 291: Momouchi, J.
# Query 292: .W
# Query 293: and the abstreact of scientific or technical documents.  The method is
# Query 294: The dictionary has been constructed based on the knowledge about concepts
# Query 295: significant phrases and their component items may be used in different
# Query 296: select significant phrases as substantial and semantic information carriers
# Query 297:     The results of the experiment for five sets of documents have shown
# Query 298: the number of them for every document and the processing time is fairly
# Query 299: using the method, is discussed with relation to the construction of the
# Query 300: .B
# Query 301: .I 72
# Query 302: Answer-Passage Retrieval by Text Searching
# Query 303: O'Connor, J.
# Query 304:     Passage retrieval (already operational for lawyers) has advantages in
# Query 305: Previous experiments in passage retrieval for scientists have demonstrated
# Query 306: reference retrieval services.  The present experiment involved a greater
# Query 307: selected independently by two different people for each retrieval question.
# Query 308: for passage retrieval, produced average recall ratios of 72 and 67%,
# Query 309: for one predictably difficult question) respectively 13 and 10 falsely
# Query 310: .B
# Query 311: .I 73
# Query 312: Partial-Match Retrieval Using Indexed Descriptor Files
# Query 313: Pfaltz, J.L.
# Query 314: Cagley, E.M.
# Query 315:     In this paper we describe a practical method of partial-match retrieval
# Query 316: associated with each record of the file.  These record descriptors are
# Query 317: which will serve as an index for the block as a whole; hence, the name
# Query 318:     First the structure of these files is described and a simple, efficient
# Query 319: storage accesses, is analyzed in detail.  Two different file creation
# Query 320: can be "tuned" to a particular application is suggested.
# Query 321: (Commun. ACM, Vol. 23, No. 9, September 1980, pp. 522-528)
# Query 322: .T
# Query 323: .A
# Query 324: .W
# Query 325: to the emergence of three additional nonprofit library networks:  the
# Query 326: Group, Inc., the University of Toronto Library Automation System (UTLAS),
# Query 327: and technological factors affecting the evolution of these networks and
# Query 328: that broker OCLC services.  The competitive and cooperative nature of
# Query 329: .B
# Query 330: .I 75
# Query 331: An Integrated Understander
# Query 332: Schank, R.C.
# Query 333: Birnbarim, L.
# Query 334:     A new type of natural language parser is presented.  The idea behind
# Query 335: representation of their meaning and inferences, as is appropriate.  The
# Query 336: integrated conception of inferences, scripts, plans and other knowledge to
# Query 337: sees.  Rather, it determines what is most interesting and concentrates on
# Query 338: .B
# Query 339: pp. 13-30)
# Query 340: .T
# Query 341: An Historical and Philosophical Overview
# Query 342: Stevens, N.D.
# Query 343:     This paper discusses the origins of library networks and traces their
# Query 344: The concept of resource sharing, with particular attention to the inter-
# Query 345: materials, is examined in relationship to library networks.  In particular,
# Query 346: library cooperation, which have tended to be separate, might become more
# Query 347: .B
# Query 348: .I 77
# Query 349: Normalization of Titles and Their Retrieval
# Query 350: Takamatsu, S.
# Query 351: Nishida, F.
# Query 352:     This paper presents a method of normalizations of English titles and
# Query 353: is converted to a function-expression by parsing.  For the retrieval with
# Query 354: expression is transformed to a predicate-governor form, and then normalized
# Query 355: in a hierarchical tree-like inverted file.
# Query 356: retrieval stages are implemented based on the key-term and case-label
# Query 357: of case-labels for each key-term.
# Query 358: (Info. Proc. & Management, Vol. 16, No. 3, 1980, pp. 155-167)
# Query 359: .T
# Query 360: .A
# Query 361: .W
# Query 362: (CATN), is prescribed.  CATN's permit a decomposition of complex language
# Query 363: domain of responsibility, where each stage (called an ATN transducer)
# Query 364: an extensive discjussion of the principles of factoring-conceptual
# Query 365: represented in a grammar, and hypothesis factoring reduces the number
# Query 366: .B
# Query 367: .I 79
# Query 368: Algorithms for Processing Partial Match Queries Using Word Fragments
# Query 369: Alagar, V.S.
# Query 370:     Algorithms are given to process partially specified queries in a
# Query 371: queries that use either whole words or word fragments as language elements.
# Query 372: and retrieval costs.  The analyses show that the method which exploits the
# Query 373: records in the file has maximum design cost and least retrieval cost.
# Query 374: (Inform. Systems, Vol. 5, No. 4, April 1980, pp. 323-332)
# Query 375: .T
# Query 376: Approach
# Query 377: Asai, I.
# Query 378:     From the detailed analysis of eight previously published mathematical
# Query 379: follows:  y = a log(x + c) + b, where y is the ratio of the cumulative
# Query 380: of the rank of journals to the total number of journals.  The parameters a, b,
# Query 381: respectively.  Each of the eight models is a special case of the general
# Query 382: three unknown parameters, a statistical method using root-weighted square
# Query 383: the fifth type of formulation with three unknown parameters is the best fit
# Query 384: droop data leads to a more accurate value of parameters and less error.
# Query 385: (JASIS, Vol. 32, No. 2, March 1981, pp. 113-121)
# Query 386: .T
# Query 387: .A
# Query 388: Shneiderman, B.
# Query 389:     The lexical problems in large information systems are created by the
# Query 390: Such lexical problems are not covered completely by the concept data
# Query 391: than the execution of operations.  In this paper we introduce our view of a
# Query 392: to deal with linguistic and control functions concerning the lexical problems
# Query 393: efficiently organized program package, which plays the role of a "linguistic
# Query 394: of databases and information retrieval systems, and facilitates the creation
# Query 395: productive for any large, especially distributed, information system.
# Query 396: (Information Processing & Management, Vol. 16, February 1980, pp. 259-267)
# Query 397: .T
# Query 398: .A
# Query 399: .W
# Query 400: past decade.  Its advantages include simplicity, consistency, and a sound
# Query 401: retrieval relationally is demonstrated.  The relational model is presented,
# Query 402: The notion of normalization is introduced and first, second, third, and
# Query 403: including the relational calculus, relational algebra, and SEQUEL.
# Query 404: relational languages.  Advantages of the relational approach to information
# Query 405: .B
# Query 406: .I 83
# Query 407: Electronic Information Interchange in an Office Environment
# Query 408: DeSousa, M.R.
# Query 409:     This paper describes an architectural approach that provides information
# Query 410: offerings.  Some of the architectures described herein are currently
# Query 411: provide the basis for document interchange capability between products
# Query 412: Office Support System (DISOSS), and the IBM Displaywriter System.
# Query 413: associated data streams and others.
# Query 414: technical description is provided.  The architectures described are
# Query 415: address the specific user interface.  The document distribution
# Query 416: facilities.
# Query 417: (IBM Systems Journal, Vol. 20, No. 1, 1981, pp. 4-22)
# Query 418: .T
# Query 419: .A
# Query 420: Desper, J.
# Query 421:     A technique is described for automatic reformulation of boolean
# Query 422: prevalence measures are derived for terms appearing in the retrieved set
# Query 423: non-relevant documents.  These measures are then used to guide the
# Query 424: the technique, a series of tests is described of its application to a small
# Query 425: feedback as employed in a SMART-type system.  MOre extensive testing is
# Query 426: .B
# Query 427: .I 85
# Query 428: Interacting in Natural Language With Artificial Systems:  The Donau Project
# Query 429: Guida, G.
# Query 430: .W
# Query 431: the conception and development of natural language understanding systems.
# Query 432: experimentation of DONAU:  a general purpose domain oriented natural
# Query 433: Polytechnic Artificial Intelligence Project.  The system is based on a two
# Query 434: generality often pointed out in many existing systems, and to facilitate
# Query 435: The horizontal level allows an independent and parallel development of the
# Query 436: legality controller).  The vertical level ensures the possibility of changing
# Query 437: particular version of the system is oriented and specialized in a simple,
# Query 438: the system and the mode of operation of each segment are illustrated in
# Query 439: are described and illustrated by means of selected examples.  Performance
# Query 440: reported and discussed.  Promising directions for future research are presented
# Query 441: .B
# Query 442: .I 86
# Query 443: Approximate String Matching
# Query 444: Hall, P.A.V.
# Query 445: .W
# Query 446: surveying techniques suitable for finding an item in a database when
# Query 447: methods found are classified as either equivalence or similarity problems.
# Query 448: For similarity problems difference measures are surveyed, with a full
# Query 449: this to the approach using probabilities and likelihoods.  Searches for
# Query 450: be an open problem still, though several promising ideas have been
# Query 451: briefly reviewed.
# Query 452: (Computing Surveys, Vol. 12, No. 4, December 1980, pp. 381-402)
# Query 453: .T
# Query 454: Bibliographic Data
# Query 455: Hayes, R.M.
# Query 456: .W
# Query 457: into an online computer system for bibliographic control.  Costs and
# Query 458: economical microfiche storage of catalog records than would be feasible
# Query 459: demonstrate the feasibility of the online microfiche catalog system for use
# Query 460: primary result of the project is the creation of a completely operational
# Query 461: necessary to demonstrate the system.  A second set of results is derived
# Query 462: times for various operations.  The cost effectiveness of the online microfiche
# Query 463: .B
# Query 464: pp. 277-289)
# Query 465: .T
# Query 466: of Its Acceptance by End Users
# Query 467: Krause, J.
# Query 468:     The question is asked whether it is feasible to use subsets of
# Query 469: using the question answering system "USER SPECIALTY LANGUAGES" (USL).
# Query 470: be discussed.  The results (error and language structure evaluation)
# Query 471: use a subset of German as query language.
# Query 472: (Inform. Systems, Vol. 5, No. 4, May 1980, pp. 297-318)
# Query 473: .T
# Query 474: in Libraries
# Query 475: Lancaster, F.W.
# Query 476:     In 1978 Collier presented some hypothetical data on economic aspects
# Query 477: services in libraries.  Collier's view of the economics of online searching
# Query 478: .  It looks only at costs but not at effectiveness in comparing the two
# Query 479:     effectiveness aspects (i.e., a cost-effectiveness analysis) would
# Query 480: .  The way the cost data are presented is grossly unfair to the online
# Query 481: This work contains corrected information regarding online and printed
# Query 482: .B
# Query 483: .I 90
# Query 484: Co-Citation Context Analysis and the Structure of Paradigms
# Query 485: Small, H.
# Query 486:     Many information scientists are concerned with the operation of
# Query 487: scientists served by these systems are often members of what have been called
# Query 488: one another and involved with highly specialized subject matters.  Often
# Query 489: this subject matter, which is sometimes referred to as a paradigm.
# Query 490: paradigms, using the techniques of citation analysis.  I will operationalize
# Query 491: Suppose we have obtained a set of papers pertaining to some topic.  Already
# Query 492: which certain specific concepts are used or discussed.  For example, we
# Query 493: papers.  Suppose further that we identify those papers in which concepts 'A'
# Query 494: Clearly not all concepts will combine in a natural way, and not all authors
# Query 495: predominant mode may emerge.  For a set of n concepts their structure is
# Query 496: two to n at a time.  The frequency with which a given combination occurs
# Query 497: regarding the particular concept combination within the corpus.  For
# Query 498: concepts as nodes and the relations between them represented as lines (arcs)
# Query 499: similar to the semantic network of artificial intelligence except that in
# Query 500: .B
# Query 501: .I 91
# Query 502: Cocited Author Retrieval Online:
# Query 503: .A
# Query 504: .W
# Query 505: entering pairs of authors' names believed to be jointly cited by
# Query 506: pairs were formed with the names of four authors prominent in the social
# Query 507: four were not specified.  It was thought that the pair Duncan and Land
# Query 508: path-analytic causal modeling.  All other pairs seemed likely to retrieve a
# Query 509: expectattions.  It was found that 121 papers generally cited social indicators
# Query 510: their titles.  Other signs of content also identified them as papers of
# Query 511: cited causal modeling documents by the input pair and were path-analytic
# Query 512: group of papers, although the two groups are akin and are formally linked
# Query 513: citing at least three of the input authors tend to be overviews of the SI
# Query 514: .B
# Query 515: .I 92
# Query 516: Database and Online Statistics for 1979
# Query 517: Williams M.E.
# Query 518:     The number of databases, records contained in databases and the online
# Query 519: bringing the 1979 totals for bibliographic, bioliographic-related, and
# Query 520: records.  Some 4 million online searches were conducted via the major U.S.
# Query 521: .B
# Query 522: .I 93
# Query 523: Experiments in Local Metrical Feedback in Full-Text Retrieval Systems
# Query 524: Attar, R.
# Query 525: .W
# Query 526: to formulate the next iteration search, was applied to a full-text database
# Query 527: Aramaic.  The iterative method consists of clustering the documents returned
# Query 528: The process produces searchonyms, which are terms synonymous to keywords in the
# Query 529: via manual or automatic feedback leads to the formulation of the next iteration
# Query 530: small-scale experiment on an English database, and indicate that in contrast
# Query 531: databases and improvements are doubtful, local metrical methods appear to be
# Query 532: simultaneously.  Further experiments using more test-queries run on even
# Query 533: performance of these methods.
# Query 534: (Information Processing & Management, Vol. 17, No. 3, 1981, pp. 115-126)
# Query 535: .T
# Query 536: .A
# Query 537: Palmer, R.C.
# Query 538:     REFLES is a microcomputer-based system for data retrieval in library
# Query 539: theoretical point of view, followed by an analysis of the reference process
# Query 540: its hardware and software.  REFLES, a prototype system at present, currently
# Query 541: and of its use are presented.  Future considerations and speculations on
# Query 542: .B
# Query 543: .I 95
# Query 544: A Comparison of Two Systems of Weighted Boolean Retrieval
# Query 545: Bookstein, A.
# Query 546:     A major deficiency of traditional Boolean systems is their inability to
# Query 547: In this article we isolate a number of criteria that should be met by any
# Query 548: only one weighting rule satisfies these conditions--that associated with fuzzy-
# Query 549: properties associated with Boolean algebra as well.  Probabilistic weighting
# Query 550: In the limit of zero/one weights, all systems considered converge to
# Query 551: .B
# Query 552: .I 96
# Query 553: Threshold Values and Boolean Retrieval Systems
# Query 554: Buell, D.A.
# Query 555: .W
# Query 556: in the problem of processing, in a document retrieval system, queries expressed
# Query 557: We shall show that the concept of threshold values resolves the problems
# Query 558: mechanisms for retrieval of documents, based on fuzzy-set-theoretic
# Query 559: .B
# Query 560: .I 97
# Query 561: A Model for a Weighted Retrieval System
# Query 562: Buell, D.A.
# Query 563: .W
# Query 564: have continuous weights assigned to the index terms that describe the records
# Query 565: Recent articles have analyzed retrieval systems with continuous weights of
# Query 566: suggested criteria which such systems ought to satisfy and record evaluation
# Query 567: analysis, based on a generalization of the discrete weights.  We also look
# Query 568: we generate an improved evaluation mechanism which seems to fulfill a larger
# Query 569: allows the user to attach a "threshold" to the query term.
# Query 570: (JASIS, Vol. 32, No. 3, May 1981, pp. 211-216)
# Query 571: .T
# Query 572: Retrieval Systems.  I. Design
# Query 573: Marcus, R.S.
# Query 574: .W
# Query 575: users, because of heterogeneity and complexity.  Investigations have concerned
# Query 576: to, and operation of, heterogeneous bibliographic retrieval systems and
# Query 577: These requests are translated by the interface into the appropriate commands
# Query 578: transformed by the interface into a common form before being given to the
# Query 579: virtual system to the user.  The interface also provides instruction and
# Query 580: of an experimental interface named CONIT are described.
# Query 581: (JASIS, Vol. 32, No. 4, July 1981, pp. 287-303)
# Query 582: .T
# Query 583: Heterogeneous Retrieval Systems.  II. Evaluations
# Query 584: Marcus, R.S.
# Query 585: .W
# Query 586: simplifying operation of multiple, heterogenous online bibliographic
# Query 587: named CONIT, was built and tested under controlled conditions with
# Query 588: showed that users were able to master interface operation sufficiently well
# Query 589: to a simple command language, adequate online instruction, and a simplified
# Query 590: operational interfaces of the type studied can provide for increased usability
# Query 591: Furthermore, more advanced interfaces based on improved instruction and
# Query 592: effectiveness for a wide class of users.
# Query 593: (JASIS, Vol. 32, No. 4, July 1981, pp. 304-317)
# Query 594: .T
# Query 595: Retrieval Systems
# Query 596: McMurdo, G.
# Query 597:     This paper notes the benefits accruing from interaction between computerized
# Query 598: of automated micrographic retrieval technology.  The conclusion is that with a
# Query 599: input from libraries and information scientists, the new generation of automated
# Query 600: future.
# Query 601: (Journal of Information Science I, 1980, pp. 345-349)
# Query 602: .T
# Query 603: .A
# Query 604: Bergmark, D.
# Query 605:     Conventional information retrieval processes are largely based on data
# Query 606: algorithms may in addition benefit from substantial computational power.
# Query 607: that serve to enhance retrieval services.  In conventional retrieval
# Query 608: greatest interest.  In more advanced systems, the use of array processors
# Query 609: and evidence is given to demonstrate the usefulness of parallel processing
# Query 610: .B
# Query 611: Verlag, Berlin-New York, 1981, pp. 328-342)
# Query 612: .T
# Query 613: .A
# Query 614: Wu, H.
# Query 615: .W
# Query 616: have been used as indicators of term importance for content analysis and
# Query 617: normally believed to be less effective than medium-frequency terms.  Recently
# Query 618: frequency characteristics but also the relevance properties of the terms.
# Query 619: precision and term utility weights that are based on the occurrence
# Query 620: documents of a collection are then introduced.  Methods are suggested for
# Query 621: occurrence characteristics in the collection.  Finally, experimental
# Query 622: relevance properties with the more conventional frequency-based methodologies.
# Query 623: (JASIS, Vol. 32, No. 3, May 1981, pp. 175-186)
# Query 624: .T
# Query 625: .A
# Query 626: MacRae, L.J.
# Query 627: Diamond, N.
# Query 628:     This paper describes the design and implementation of an "electronic filing
# Query 629: documents in such a way a particular document may be easily and quickly
# Query 630: of the system in a mixture of hardware and software.
# Query 631: (Computer, Vol. 14, No. 5, May 1981, pp. 24-36)
# Query 632: .T
# Query 633: .A
# Query 634: Harper, D.J.
# Query 635: .W
# Query 636: using relevance feedback, given the search terms in the query.  These search
# Query 637: index term vocabulary.  A number of different spanning trees are generated from
# Query 638: different spanning trees is shown to be approximately the same.  Effectiveness
# Query 639: on three different test collections.
# Query 640: (Information Processing & Management, Vol. 17, No. 2, 1981, pp. 77-91)
# Query 641: .T
# Query 642: .A
# Query 643: .W
# Query 644: document is accurately represented.  Indexing effectiveness measures whether
# Query 645: query.  Measurement of these criteria is cumbersome and costly; data base
# Query 646: quality or effectiveness.  The present article assesses the validity of this
# Query 647: .B
# Query 648: .I 106
# Query 649: Text Passage Retrieval Based on Colon Classification:  Retrieval Performance
# Query 650: Shepherd, M.A.
# Query 651:     A set of experiments was conducted to determine the suitability of the
# Query 652: and retrieval of primary information from the full text of documents.  Primary
# Query 653: to secondary information which is generally in such forms as:  an abstract, a
# Query 654:     Full text databases were created in two subject areas and queries solicited
# Query 655: with four automated passage retrieval systems, was created to test the various
# Query 656: word occurrence system were created in order to compare the retrieval results
# Query 657: performances were measured using recall and precision and the mean expected
# Query 658:     Overall, it was found that the Colon Classification-based systems did not
# Query 659: .B
# Query 660: .I 107
# Query 661: User-Responsive Subject Control in Bibliographic Retrieval Systems
# Query 662: Tague, J.M.
# Query 663:     A study was carried out of the relationship between the vocabulary of
# Query 664: the value of adding to the document description record in a retrieval system
# Query 665: Two test databases incorporating user query keywords were implemented at
# Query 666: Ontario.  Clustering of the documents via title and user keywords, a
# Query 667: tests were used to examine the effect of the added keywords.  Results
# Query 668: indicated the value of analyses with sample data in the development and
# Query 669: .B
# Query 670: .I 108
# Query 671: A Program for Machine-Mediated Searching
# Query 672: Toliver, D.
# Query 673:     A technique of online instruction and assistance to bibliographic data
# Query 674: being developed by Drexel University.  IIDA assists searchers by providing
# Query 675: Extensive help facilities which draw on this analysis are available to
# Query 676: is concerned with the process of searching and the behavior of searchers.
# Query 677: is being developed by subcontract with the Franklin Institute's Science
# Query 678: .B
# Query 679: .I 109
# Query 680: Author Cocitation:  A Literature Measure of Intellectual Structure
# Query 681: White, H.D.
# Query 682: .W
# Query 683: case information science, can be done using authors as units of analysis and
# Query 684: distances from each other.  The analysis assumes that the more two authors
# Query 685: are cocitation counts drawn online from Social Scisearch (Social Sciences
# Query 686: (1) identifiable author groups (akin to "schools") of information science,
# Query 687: centrality and peripherality of authors within groups, (4) proximities of
# Query 688: to connect various areas of research), and (5) positions of authors with
# Query 689: divergent groups in order to aid interpretation.  Cocitation analysis of
# Query 690: intellectual structure in the sciences and possibly in other areas to the
# Query 691: establishes authors, as well as documents, as an effective unit in
# Query 692: .B
# Query 693: .I 110
# Query 694: Progress in Documentation.  Word Processing:
# Query 695: .A
# Query 696: .W
# Query 697: Electronic Mail, "Electronic Communications," "Convergence," "Information
# Query 698: used to describe current activities in the office technology area.  The high
# Query 699: improve productivity by automating the dull, routine jobs are usually quoted
# Query 700: the equally tedious routine jobs in the office environment; the investment
# Query 701: office.  This, however, is changing rapidly and investment on a large scale
# Query 702: forcing many companies and organizations to take a much closer look at their
# Query 703: .B
# Query 704: .I 111
# Query 705: Document Clustering Using an Inverted File Approach
# Query 706: Willett, P.
# Query 707:     An automated document clustering procedure is described which does not
# Query 708: of the order in which the documents are processed.  The procedure makes use of
# Query 709: indexing vocabulary used to characterise the documents in the file.  The
# Query 710: obtained from serial searching and from use of the single-linkage clustering
# Query 711: .B
# Query 712: .I 112
# Query 713: A Fast Procedure for the Calculation of Similarity Coefficients in
# Query 714: .A
# Query 715: .W
# Query 716: documents in automatic classification experiments.  The speed of the procedure
# Query 717: document are identified together, using an inverted file to the terms in the
# Query 718: compared with previously described procedures.
# Query 719: (Information Processing & Management, Vol. 17, No. 2, 1981, pp. 53-60)
